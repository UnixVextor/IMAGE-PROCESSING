# %% [markdown]
# ### LAB 1

# %%
import numpy as np
import cv2
import math
import matplotlib.image as mpimg


# %matplotlib widget
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Lab#1.1.1

# %%
img = cv2.imread("image/jumpingFish.jpg")
rgb_image = np.copy(img)
rgb_image[:,:,0], rgb_image[:,:,2] = img[:,:,2],img[:,:,0] 
Xb = img[:,:,0]
Xg = img[:,:,1]
Xr = img[:,:,2]
file_names = [img,Xb, Xg, Xr,rgb_image, rgb_image[:,:,0], rgb_image[:,:,1], rgb_image[:,:,2]]
_, axs = plt.subplots(2,4, figsize=(12,4))
axs = axs.flatten()

for img, ax in zip(file_names, axs):
    # plt.title("abs")
    ax.imshow(img, cmap='gray')
plt.show()
# print(img.shape)
# ax.imshow(Xg, cmap='gray')
# plt.imshow(Xb, cmap='gray')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
